# %%
from main import *  # main must be imported in order to trigger the computation
from map import m

# Feature tables

# pprint(summary_sleep)
pprint(sorted(summary_friend))
# pprint(summary_state)
# pprint(sorted([(collapse_date_ranges(v), k) for k, v in summary_park.iteritems()]))
# pprint(sorted(summary_animal))
# pprint(summary_got_high)
# pprint(summary_extreme_nsew)
# pprint(summary_facebook)
# pprint(summary_meal)
# pprint(summary_pie)
# pprint(summary_tiki)
# pprint(summary_wedding)
# pprint(summary_other)

# pprint(executive_summary)

m
# Out:
# [('2018-05-01', 'Nina and Alex'),
#  ('2018-05-03 to 2018-05-06', 'Lisa and Bill'),
#  ('2018-05-06 to 2018-05-08', 'Laura and Austin'),
#  ('2018-05-09 to 2018-05-12', 'Jessica, Tommy, Conner, and Brady'),
#  ('2018-05-10', 'Tom, Lynda, Jennifer, and Andrew'),
#  ('2018-05-12 to 2018-05-14', 'Amanda, Hunter, Hunter, and Jamie'),
#  ('2018-05-14 to 2018-05-19', 'Alex, Tristan, and Heli'),
#  ('2018-05-26', 'Laurel and Andy'),
#  ('2018-05-29 to 2018-06-01', 'Laurel and Andy'),
#  ('2018-06-01 to 2018-06-03', 'Piper and Anwar'),
#  ('2018-06-03 to 2018-06-05', 'Courtney'),
#  ('2018-06-11 to 2018-06-14', 'Dani and Petra'),
#  ('2018-06-14', 'Nicole Waugh Ryan'),
#  ('2018-06-15 to 2018-06-17', 'Derek and Marisa'),
#  ('2018-06-15 to 2018-06-17', 'Laura and Austin'),
#  ('2018-06-16', 'Georgia, Reid, Sus, Olin, Sarah and Cam'),
#  ('2018-06-16', 'Jack and Emilie'),
#  ('2018-06-16', 'Jones'),
#  ('2018-06-20 to 2018-06-23', 'Richard and Janice'),
#  ('2018-06-22', 'Hanya and family'),
#  ('2018-06-23 to 2018-06-26', 'Meliza and Nick'),
#  ('2018-06-26', 'Jones'),
#  ('2018-06-26 to 2018-06-28', 'Johnny'),
#  ('2018-07-06 to 2018-07-07', 'Collin'),
#  ('2018-07-07', 'Lee'),
#  ('2018-07-07 to 2018-07-11', 'Jeremy and Christine'),
#  ('2018-07-09', 'Larry'),
#  ('2018-07-11 to 2018-07-15', 'Brenda'),
#  ('2018-07-15', 'Laurie'),
#  ('2018-07-15 to 2018-07-19', 'Vic and Ari'),
#  ('2018-07-16', 'Caleb and Amber'),
#  ('2018-07-17 to 2018-07-18', 'Anita'),
#  ('2018-07-17 to 2018-07-18', 'Julia, Cachi, and Alex'),
#  ('2018-07-17 to 2018-07-18', 'Mom and Dad'),
#  ('2018-07-18', 'Flo'),
#  ('2018-07-18', 'Louise, David, and Christopher'),
#  ('2018-07-19 to 2018-07-21', 'Derek and Audrey'),
#  ('2018-07-19 to 2018-07-21', 'Phil and Griffin'),
#  ('2018-07-19 to 2018-07-21', 'Ray and Jeff'),
#  ('2018-07-19 to 2018-07-22', 'Nina and Alex'),
#  ('2018-07-20 to 2018-07-22', 'Half of Banduh'),
#  ('2018-07-21', 'Jeff and Sharon'),
#  ('2018-07-22', 'Julie and Patsy'),
#  ('2018-07-22', 'Murray'),
#  ('2018-07-23 to 2018-07-24', 'Eric, Crissy, Adara, and Nash'),
#  ('2018-07-28 to 2018-07-29', 'Derek and Marisa'),
#  ('2018-07-29 to 2018-07-30',
#   'Mike and Kristine, the Alberti family, Pablo, Jake and Adam, Eric Tooley'),
#  ('2018-08-08 to 2018-08-11', 'Derek and Marisa'),
#  ('2018-08-09', 'Jack and Emilie'),
#  ('2018-08-09 to 2018-08-10', 'Arbel'),
#  ('2018-08-14 to 2018-08-16', 'Ann Tan'),
#  ('2018-08-16', 'Phil and Griffin'),
#  ('2018-08-16', 'Ray and Jeff'),
#  ('2018-08-16 to 2018-08-20', 'Nina and Alex'),
#  ('2018-08-17', 'Alex B'),
#  ('2018-08-17', 'Egor'),
#  ('2018-08-17', 'Mike'),
#  ('2018-08-17', 'Olga'),
#  ('2018-08-18', 'Sally and Linden, Mike and Anna'),
#  ('2018-08-19', 'Bill and Ginger'),
#  ('2018-08-19', 'Mom and Dad'),
#  ('2018-08-20 to 2018-08-21', 'Vic and Ari'),
#  ('2018-09-07 to 2018-09-08', 'Egor and Quynh, Alex B, Mike, and Kyle'),
#  ('2018-09-08',
#   'Tristan, Heli, Monique, Katie and Glenn, Eric and Greta, David and Dianne'),
#  ('2018-09-09', 'Kyle'),
#  ('2018-09-09 to 2018-09-10', 'Alex B'),
#  ('2018-09-26', 'Daniel and Jilmarie')]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
